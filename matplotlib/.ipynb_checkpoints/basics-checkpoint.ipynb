# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
fig = plt.figure(figsize=(10,8))
plt.xlabel('This is x axis')
plt.ylabel('This is y axis')
plt.title('This is my first visualization')
plt.axis([0,10,0,10])
plt.show()

# %% [markdown]
# ### Line Plot

# %%
sales = [ 10,24,34,25,67,2,13,45,75]
months = ["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep"]
import matplotlib.pyplot as plt

plt.plot(months,sales,color='red',label='Sales',linestyle ='dashed')
plt.xlabel('Sales Month')
plt.ylabel('Sales in Millions')
plt.title('Sales Report')
plt.legend()
plt.show()

# %%
df = pd.read_csv("../data/company_sales_data.csv")
#df.info()
months = df['month_number'].tolist()
facewash = df['facewash'].tolist()
facecream = df['facecream'].tolist()

plt.plot(months,facewash,color='blue',label="facewash")
plt.plot(months,facecream,color='red',label='facecream')
plt.legend()
plt.show()

# %%
x = ['Apple','Banana','Orange','Pears','Pineapple']
y = [30,24,52,14,20]
plt.barh(x,y)
# Out:
# <BarContainer object of 5 artists>

# %%
df = pd.DataFrame([['Ohio',10,20,30,40],['Texas',56,78,43,67],['CA',98,43,76,65]],columns=['State','Round1','Round2','Round3','Round4'])
df
# Out:
#    State  Round1  Round2  Round3  Round4
# 0   Ohio      10      20      30      40
# 1  Texas      56      78      43      67
# 2     CA      98      43      76      65

# %%
df = pd.read_csv('../data/company_sales_data.csv')
months = df['month_number'].tolist()
facewash = df['facewash'].tolist()
facecream = df['facecream'].tolist()
plt.bar(months,facecream)
# Out:
# <BarContainer object of 12 artists>

# %%
plt.stackplot(months,facecream,facewash)

# %%
df.plot(x='State',kind='bar',stacked='False')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Documents/MachineLearning/DataAnalysis/mlEnv/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'State'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
ages= [76,33,45,23,55,24,76,24,74,65,27,88,65]
bins = [10,20,30,40,50,60,70,80,90]
plt.hist(ages,bins,histtype=bar,rwidth=0.5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/jeevanapathipati/Documents/Class Lab/matplotlib/basics.ipynb Cell 11 line 3
#       <a href='vscode-notebook-cell:/Users/jeevanapathipati/Documents/Class%20Lab/matplotlib/basics.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> ages= [76,33,45,23,55,24,76,24,74,65,27,88,65]
#       <a href='vscode-notebook-cell:/Users/jeevanapathipati/Documents/Class%20Lab/matplotlib/basics.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a> bins = [10,20,30,40,50,60,70,80,90]
# ----> <a href='vscode-notebook-cell:/Users/jeevanapathipati/Documents/Class%20Lab/matplotlib/basics.ipynb#X11sZmlsZQ%3D%3D?line=2'>3</a> plt.hist(ages,bins,histtype=bar,rwidth=0.5)
#
# NameError: name 'bar' is not defined

# %%
sales = [100,300,550,345,656,867,242,325,635,2355,1]
plt.boxplot(sales)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x127fcd3d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x127fd0990>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x125c50310>],
#  'medians': [<matplotlib.lines.Line2D at 0x127fd2150>],
#  'fliers': [<matplotlib.lines.Line2D at 0x127fd2d90>],
#  'means': []}

# %%
fig=plt.figure(figsize=(2,1))
fig,ax = plt.subplots(2,2,sharex=True)

ax[0,0].set_title("This is first")
ax[0,1].set_title("This is second")
ax[1,0].set_title("This is third")
ax[1,1].set_title("This is fourth")
# Out:
# Text(0.5, 1.0, 'This is fourth')

# %%
import seaborn as sns
from seaborn import lineplot
df = pd.read_csv('../data/monthly-car-sales.csv')
lineplot(x='Month',y='Sales',data=df)
sns.__version__
# Out:
# '0.13.2'

# %%
from seaborn import countplot
dataset = pd.read_csv("../data/breast-cancer.csv",header=None)
print(dataset.head())
countplot(x=0,data=dataset)
# Out:
#          0          1        2      3      4    5        6           7      8  \
# 0  '40-49'  'premeno'  '15-19'  '0-2'  'yes'  '3'  'right'   'left_up'   'no'
# 1  '50-59'     'ge40'  '15-19'  '0-2'   'no'  '1'  'right'   'central'   'no'
# 2  '50-59'     'ge40'  '35-39'  '0-2'   'no'  '2'   'left'  'left_low'   'no'
# 3  '40-49'  'premeno'  '35-39'  '0-2'  'yes'  '3'  'right'  'left_low'  'yes'
# 4  '40-49'  'premeno'  '30-34'  '3-5'  'yes'  '2'   'left'  'right_up'   'no'
#
#                         9
# 0     'recurrence-events'
# 1  'no-recurrence-events'
# 2     'recurrence-events'
# 3  'no-recurrence-events'
# 4     'recurrence-events'
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/jeevanapathipati/Documents/Class Lab/matplotlib/basics.ipynb Cell 15 line 4
# ...
